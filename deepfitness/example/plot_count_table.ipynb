# %%
"""
    Example Jupyter notebook, using preprocess.visualize to inspect
    the example CSV in the expected format following preprocess.
"""

# %load_ext autoreload
# %autoreload 2

import pandas as pd, numpy as np, seaborn as sns, matplotlib.pyplot as plt

from plotting import plot_count_table as pre_visualize

df = pd.read_csv('TEAD_subset500.csv')

genotype_col = 'HELMnolinker'
round_cols = ['0', '1', '2', '3', '4', '5', '6']

df[genotype_col] = [x.strip('$PEPTIDE1,PEPTIDE1,5:R3-1:R3$$$') for x in df[genotype_col]]

table = pre_visualize.CountTable(df, genotype_col, round_cols)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
table.get_summary_stats()
# Out:
#                            0         1         2          3          4
# Total reads             19.0    5583.0  329690.0  1432001.0  3492289.0  \
# Unique genotypes          19       436       498        498        500
# Max frequency       0.052632  0.009851  0.021284   0.033024   0.049444
# Normalized entropy  0.473793  0.924975   0.86418   0.820526   0.773151
#
#                             5          6
# Total reads         1541308.0  3686614.0
# Unique genotypes          500        500
# Max frequency        0.069792   0.087998
# Normalized entropy     0.7227   0.679923

# %%
ax = table.summary_heatmap()
ax.set_title('Example TEAD3_10k dataset')
# Out:
# Text(0.5, 1.0, 'Example TEAD3_10k dataset')

# %%
table.summary_trajectory_plot()
# Out:
# <Axes: xlabel='Round', ylabel='Frequency'>
